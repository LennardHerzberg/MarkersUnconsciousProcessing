# %%
import os
import os.path as op
import shutil

import mne
from mne import read_evokeds

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob

#https://mne.tools/stable/overview/implementation.html

# %%
#dataPath = 'C:/Users/juhoffmann/Desktop/EEG_BIDS/EEG_250Hz/PreprocData/'
subjects = glob.glob('/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/*.edf') 

#Analysis settings
tmin = -0.2
tmax = 0.8
baseline = (-0.2, 0)

montage = mne.channels.read_custom_montage('/Volumes/EMOCON/data_EEG/BC-MR-64.bvef') #set montage 
subjects
# Out:
# ['/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-004_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-006_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-010_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-011_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-014_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-015_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-017_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-019_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-021_BackwardMask_Preprocessed.edf',
#  '/Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-022_BackwardMask_Preprocessed.edf',
# ...

# %%
len(subjects)
# Out:
# 51

# %%
primer_happy_strong = []
primer_happy_weak = []
primer_sad_strong = []
primer_sad_weak = []
primer_neutral_strong = []
primer_neutral_weak = []

for i in subjects:

    # Load Dataset
    eeg = mne.io.read_raw_edf(i, preload = True)
    eeg.set_channel_types(mapping={'ECG': 'ecg'}) #define ECG channel 
    #montage.plot() 
    eeg.set_montage(montage, match_case=False) #set montage to raw dataset
    
    #Find events
    events, event_id = mne.events_from_annotations(eeg)
    
    #Define epochs
    epochs = mne.Epochs(eeg, events,
                        event_id = event_id,
                        preload = True,
                        tmin= tmin, 
                        tmax= tmax, 
                        event_repeated='merge',
                        baseline = baseline) #set baseline from -0.2s to - 0 seconds
    
    evoked_primer_happy_strong = epochs['h_h_strong','h_n_strong','h_s_strong'].average()
    evoked_primer_happy_weak = epochs['h_h_weak','h_n_weak','h_s_weak'].average()
    evoked_primer_sad_strong = epochs['s_h_strong','s_n_strong','s_s_strong'].average()
    evoked_primer_sad_weak = epochs['s_h_weak','s_n_weak','s_s_weak'].average()
    evoked_primer_neutral_strong = epochs['n_h_strong','n_n_strong','n_s_strong'].average()
    evoked_primer_neutral_weak = epochs['n_h_weak','n_n_weak','n_s_weak'].average()
    
    #append all evokeds  
    primer_happy_strong.append(evoked_primer_happy_strong)
    primer_happy_weak.append(evoked_primer_happy_weak)
    primer_sad_strong.append(evoked_primer_sad_strong)
    primer_sad_weak.append(evoked_primer_sad_weak)    
    primer_neutral_strong.append(evoked_primer_neutral_strong)
    primer_neutral_weak.append(evoked_primer_neutral_weak) 

    
    del eeg  # reduce memory usage
# Out:
# Extracting EDF parameters from /Volumes/EMOCON/data_EEG/EEG_250Hz/edf/Lennard/sub-004_BackwardMask_Preprocessed.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 126749  =      0.000 ...   506.996 secs...
# Used Annotations descriptions: ['New Segment', 'R', 'R128', 'S 50', 'S 60', 'S 70', 'S120', 'S130', 'S140', 'S150', 'S160', 'S170', 'Time 0', 'h_h_strong', 'h_h_weak', 'h_n_strong', 'h_n_weak', 'h_s_strong', 'h_s_weak', 'n_h_strong', 'n_h_weak', 'n_n_strong', 'n_n_weak', 'n_s_strong', 'n_s_weak', 's_h_strong', 's_h_weak', 's_n_strong', 's_n_weak', 's_s_strong', 's_s_weak']
# Multiple event values for single event times found. Creating new event value to reflect simultaneous events.
# Not setting metadata
# 814 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 814 events and 251 original time points ...
# 1 bad epochs dropped
# ...

# %%
average_primer_happy_strong = mne.combine_evoked(primer_happy_strong, weights='equal')
average_primer_happy_weak = mne.combine_evoked(primer_happy_weak, weights='equal')
average_primer_sad_strong = mne.combine_evoked(primer_sad_strong, weights='equal')
average_primer_sad_weak = mne.combine_evoked(primer_sad_weak, weights='equal')
average_primer_neutral_strong = mne.combine_evoked(primer_neutral_strong, weights='equal')
average_primer_neutral_weak = mne.combine_evoked(primer_neutral_weak, weights='equal')

# %%
# strongly masked 

fig1 = average_primer_happy_strong.plot_topomap(times=[0.107, 0.175], average = 0.05)
fig2 = average_primer_sad_strong.plot_topomap(times=[0.107, 0.175], average = 0.05)
fig3 = average_primer_neutral_strong.plot_topomap(times=[0.107, 0.175], average = 0.05)
# Out:
# <MNEFigure size 450x220 with 3 Axes>
# <MNEFigure size 450x220 with 3 Axes>
# <MNEFigure size 450x220 with 3 Axes>

# %%
# weakly masked 

fig4 = average_primer_happy_weak.plot_topomap(times=[0.107, 0.175], average = 0.05)
fig5 = average_primer_sad_weak.plot_topomap(times=[0.107, 0.175], average = 0.05)
fig6 = average_primer_neutral_weak.plot_topomap(times=[0.107, 0.175], average = 0.05)
# Out:
# <MNEFigure size 450x220 with 3 Axes>
# <MNEFigure size 450x220 with 3 Axes>
# <MNEFigure size 450x220 with 3 Axes>
